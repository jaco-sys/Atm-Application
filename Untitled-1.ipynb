# %%
def atm():

    balance = 10000
    
    while True:
        print("\n1. Check Balance")
        print("2. Deposit")
        print("3. Withdraw")
        print("4. Exit")

        print('Welcome to choose our reputatable bank')
        choice =int(input('enter your choice:'))

        if choice==1:
            print(f'this is bank balance:{balance}')

        
        elif choice==2:
            amount=int(input('enter your deposit money:'))
            balance+=amount
            print(f'this is updated your account:{balance}')


        elif choice==3:
            if amount<balance:
                amount=int(input('enter your amount you need to withdraw:'))
                balance-=amount
                print(f'the amount you withdraw successfully the bank balance:{balance}')
            
            else:
                print('inbalance sufficient')

        elif choice==4:
            print('thankyou for choosing this bank for your future we will always welcome')


atm()
# Out:
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Welcome to choose our reputatable bank
